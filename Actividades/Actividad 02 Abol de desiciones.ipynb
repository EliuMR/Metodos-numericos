# %% [markdown]
# # Ejercicio 3_8
# ## Eliú Moreno Ramírez
# Arbol de decisiones

# %%
I=input ('The interest rate is <8%')
if I=="Y" or I=="y":
    In=input('The Income is <$75,000')
    if In=="Y" or In=="y":
        print ('Risk of prepayment 2.6%')
    elif In=="N" or In=="n":
        print ('Risk of prepayment 6.4%')
    else:
        print ('Error, enter "Y", "y" for Yes or "N", "n" for No')
elif I=="N" or I=="n":
    Mo=input ('The mortagage is <183,000')
    if Mo=="Y" or Mo=="y":
        print ('Risk of prepayment 13.9%')
    elif Mo=="N" or Mo=="n":
        print ('Risk of prepayment 36.0%')
    else:
        print ('Error, enter "Y", "y" for Yes or "N", "n" for No')
else:
    print ('Error, enter "Y", "y" for Yes or "N", "n" for No')
# Out:
# The interest rate is <8%y
# The Income is <$75,000y
# Risk of prepayment 2.6%
