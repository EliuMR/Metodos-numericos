# %%
import pandas as pd

# %%
data=pd.read_csv('Datasets/Datasets_Customer Churn Model.txt')

# %%
data
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       KS             128        415  382-4657         no        yes
# 1       OH             107        415  371-7191         no        yes
# 2       NJ             137        415  358-1921         no         no
# 3       OH              84        408  375-9999        yes         no
# 4       OK              75        415  330-6626        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 3328    AZ             192        415  414-4276         no        yes
# 3329    WV              68        415  370-3271         no         no
# 3330    RI              28        510  328-8230         no         no
# 3331    CT             184        510  364-6381        yes         no
# 3332    TN              74        415  400-4344         no        yes
#
#       VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# ...

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
data.columns.values
# Out:
# array(['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan",
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls',
#        'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins',
#        'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
#        'Intl Charge', 'CustServ Calls', 'Churn?'], dtype=object)

# %%
dayset=data[['Account Length','Phone','Day Charge','Day Calls']]

# %%
dayset
# Out:
#       Account Length     Phone  Day Charge  Day Calls
# 0                128  382-4657       45.07        110
# 1                107  371-7191       27.47        123
# 2                137  358-1921       41.38        114
# 3                 84  375-9999       50.90         71
# 4                 75  330-6626       28.34        113
# ...              ...       ...         ...        ...
# 3328             192  414-4276       26.55         77
# 3329              68  370-3271       39.29         57
# 3330              28  328-8230       30.74        109
# 3331             184  364-6381       36.35        105
# 3332              74  400-4344       39.85        113
#
# [3333 rows x 4 columns]

# %%
columnas_deseadas=['Account Lenght','VMail Message','Day Calls']

# %%
all_columns_list=data.columns.values.tolist()

# %%
columnas_deseadas
# Out:
# ['Account Lenght', 'VMail Message', 'Day Calls']

# %%
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist=[x for x in all_columns_list if x not in columnas_deseadas]
sublist
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subst=data[sublist]

# %%
subst.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  Day Mins  \
# 0    KS             128        415  382-4657         no        yes     265.1
# 1    OH             107        415  371-7191         no        yes     161.6
# 2    NJ             137        415  358-1921         no         no     243.4
# 3    OH              84        408  375-9999        yes         no     299.4
# 4    OK              75        415  330-6626        yes         no     166.7
#
#    Day Charge  Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  \
# 0       45.07     197.4         99       16.78       244.7           91
# 1       27.47     195.5        103       16.62       254.4          103
# 2       41.38     121.2        110       10.30       162.6          104
# 3       50.90      61.9         88        5.26       196.9           89
# 4       28.34     148.3        122       12.61       186.9          121
#
# ...

# %%
subst[1:25]
# Out:
#    State  Account Length  Area Code     Phone Int'l Plan VMail Plan  Day Mins  \
# 1     OH             107        415  371-7191         no        yes     161.6
# 2     NJ             137        415  358-1921         no         no     243.4
# 3     OH              84        408  375-9999        yes         no     299.4
# 4     OK              75        415  330-6626        yes         no     166.7
# 5     AL             118        510  391-8027        yes         no     223.4
# 6     MA             121        510  355-9993         no        yes     218.2
# 7     MO             147        415  329-9001        yes         no     157.0
# 8     LA             117        408  335-4719         no         no     184.5
# 9     WV             141        415  330-8173        yes        yes     258.6
# 10    IN              65        415  329-6603         no         no     129.1
# 11    RI              74        415  344-9403         no         no     187.7
# ...

# %% [markdown]
# ### Condicionales

# %%
data1=data[data['Day Mins']>300]

# %%
data1.shape #filas,columnas
# Out:
# (43, 21)

# %%
data2=data[data['State']=='NY']

# %%
data2.shape
# Out:
# (83, 21)

# %% [markdown]
# * And -> $ se usa para una doble condición
# * OR ->| una condición o la otra

# %%
data3=data[(data['Day Mins']>300)&(data['State']=='NY')]

# %%
data3
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 985    NY              64        415  345-9140        yes         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 985              0     346.8         55       58.96  ...         79
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# 15        27.01       160.6          128          7.23        5.4           9
# 985       21.21       275.4          102         12.39       13.3           9
#
#      Intl Charge  CustServ Calls  Churn?
# 15          1.46               4   True.
# 985         3.59               1   True.
#
# [2 rows x 21 columns]

# %%
data4=data[(data['Day Mins']>300)|(data['State']=='NY')]

# %%
data4.shape
# Out:
# (124, 21)

# %%
data5=data[data['Day Mins']<data['Night Mins']]

# %%
data5.shape
# Out:
# (2051, 21)

# %%
data6=data[data['Day Mins']>data['Night Mins']]
data6.shape
# Out:
# (1280, 21)
